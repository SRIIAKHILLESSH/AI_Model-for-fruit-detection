# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("moltean/fruits")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 964M/964M [00:06<00:00, 149MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/moltean/fruits/versions/11

# %%
import kagglehub

# Download the fruits dataset
path = kagglehub.dataset_download("moltean/fruits")
# Out:
# ...
# 100%|██████████| 964M/964M [00:12<00:00, 79.0MB/s]
# Extracting files...

# %%
import os
import cv2
import matplotlib.pyplot as plt

# List the contents of the dataset directory
data_dir = os.path.join(path, 'fruits-360_dataset', 'fruits-360')
print(os.listdir(data_dir))

# Load and display an image
sample_image_path = os.path.join(data_dir, 'Training', 'Apple Braeburn', '0_100.jpg')
img = cv2.imread(sample_image_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-62c5fb898bda> in <cell line: 7>()
#       5 # List the contents of the dataset directory
#       6 data_dir = os.path.join(path, 'fruits-360_dataset', 'fruits-360')
# ----> 7 print(os.listdir(data_dir))
#       8
#       9 # Load and display an image
#
# FileNotFoundError: [Errno 2] No such file or directory: '/root/.cache/kagglehub/datasets/moltean/fruits/versions/11/fruits-360_dataset/fruits-360'

# %%
import os

# Print directory structure
for root, dirs, files in os.walk(path):
    print(root, "contains", len(dirs), "directories and", len(files), "files.")
# Out:
# /root/.cache/kagglehub/datasets/moltean/fruits/versions/11 contains 2 directories and 0 files.
# /root/.cache/kagglehub/datasets/moltean/fruits/versions/11/fruits-360_dataset_original-size contains 1 directories and 0 files.
# /root/.cache/kagglehub/datasets/moltean/fruits/versions/11/fruits-360_dataset_original-size/fruits-360-original-size contains 5 directories and 1 files.
# /root/.cache/kagglehub/datasets/moltean/fruits/versions/11/fruits-360_dataset_original-size/fruits-360-original-size/Meta contains 24 directories and 0 files.
# /root/.cache/kagglehub/datasets/moltean/fruits/versions/11/fruits-360_dataset_original-size/fruits-360-original-size/Meta/apple_braeburn_1 contains 0 directories and 1 files.
# /root/.cache/kagglehub/datasets/moltean/fruits/versions/11/fruits-360_dataset_original-size/fruits-360-original-size/Meta/carrot_1 contains 0 directories and 1 files.
# ...

# %%
data_dir = os.path.join(path, 'fruits-360_dataset', 'fruits-360', 'Training')
print(os.listdir(data_dir))  # Should list fruit category folders
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-9b7062ea3b84> in <cell line: 2>()
#       1 data_dir = os.path.join(path, 'fruits-360_dataset', 'fruits-360', 'Training')
# ----> 2 print(os.listdir(data_dir))  # Should list fruit category folders
#
# FileNotFoundError: [Errno 2] No such file or directory: '/root/.cache/kagglehub/datasets/moltean/fruits/versions/11/fruits-360_dataset/fruits-360/Training'

# %%
# !nvidia-smi
# Out:
# Mon Jan 13 03:15:39 2025
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   48C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !pip install tensorflow-gpu
# Out:
# ...
#   Using cached tensorflow-gpu-2.12.0.tar.gz (2.6 kB)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
import numpy as np
import pandas as pd
import matplotlib. pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
data_train_path = '/content/drive/MyDrive/fruits/fruits-360_dataset_original-size/fruits-360_dataset_original-size/Training'
data_test_test = '/content/drive/MyDrive/fruits/fruits-360_dataset_original-size/fruits-360_dataset_original-size/Test'
data_train_val='/content/drive/MyDrive/fruits/fruits-360_dataset_original-size/fruits-360_dataset_original-size/Validation'

# %%
img_width=180
img_height=180

# %%
import tensorflow as tf
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Define dataset path
data_train_path = '/content/drive/MyDrive/fruits/fruits-360_dataset_original-size/fruits-360-original-size/Training'

# Define image dimensions
img_width, img_height = 100, 100

# Load the dataset
data_train_main = tf.keras.utils.image_dataset_from_directory(
    data_train_path,
    shuffle=True,
    image_size=(img_width, img_height),
    batch_size=32,
    validation_split=None
)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Found 0 files belonging to 24 classes.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-b2c558295ac6> in <cell line: 14>()
#      12
#      13 # Load the dataset
# ---> 14 data_train_main = tf.keras.utils.image_dataset_from_directory(
#      15     data_train_path,
#      16     shuffle=True,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/image_dataset_utils.py in image_dataset_from_directory(directory, labels, label_mode, class_names, color_mode, batch_size, image_size, shuffle, seed, validation_split, subset, interpolation, follow_links, crop_to_aspect_ratio, pad_to_aspect_ratio, data_format, verbose)
#     319         )
#     320         if not image_paths:
# --> 321             raise ValueError(
# ...

# %%
train_ds=keras.preprocessing.image_dataset_from_directory(
    "Training",
    shuffle=True,
    image_size=(256,256),
    batch_size=32



)
val_ds=keras.preprocessing.image_dataset_from_directory(
    "Validation",
    shuffle=True,
    image_size=(256,256),
    batch_size=32



)
test_ds=keras.preprocessing.image_dataset_from_directory(
    "Test",
    shuffle=True,
    image_size=(256,256),
    batch_size=32



)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# <ipython-input-8-536c93e5b0cd> in <cell line: 1>()
# ----> 1 train_ds=keras.preprocessing.image_dataset_from_directory(
#       2     "Training",
#       3     shuffle=True,
#       4     image_size=(256,256),
#       5     batch_size=32
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/image_dataset_utils.py in image_dataset_from_directory(directory, labels, label_mode, class_names, color_mode, batch_size, image_size, shuffle, seed, validation_split, subset, interpolation, follow_links, crop_to_aspect_ratio, pad_to_aspect_ratio, data_format, verbose)
#     222     if seed is None:
#     223         seed = np.random.randint(1e6)
# --> 224     image_paths, labels, class_names = dataset_utils.index_directory(
#     225         directory,
#     226         labels,
#
# ...

# %%
import os
print(os.listdir('/content/drive/MyDrive/fruits'))
# Out:
# ['.DS_Store', 'fruits-360_dataset_original-size', 'fruits-360_dataset_100x100']

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
